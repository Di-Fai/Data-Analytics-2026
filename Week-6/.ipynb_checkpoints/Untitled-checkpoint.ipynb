# %% [markdown]
# # Dta Analytics Notes
# ## Goals
# - Clean data
# - Analyze trends
# - Build model
#
# ### Sample Code

# %%
''' python'''
x = 10
y = 20
print(x + y)
# Out:
# 30

# %%
cd
# Out:
# C:\Users\dimit
