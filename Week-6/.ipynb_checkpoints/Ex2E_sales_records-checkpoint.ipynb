# %% [markdown]
# # Sales Records Analysis
# ### Author: Dimitri Nji
# ### Exercise 2.E Using functions for analyzing data
#
# This notebook analyzes a small sales dataset using Python functions.
# Each function takes the full dataset as its first argument.

# %%
sales_data = [
    ('Laptop', 'East', 1200.00),
    ('Phone', 'West', 850.00),
    ('Tablet', 'East', 400.00),
    ('Monitor', 'South', 650.00),
    ('Keyboard', 'West', 75.00),
    ('Laptop', 'South', 1150.00),
    ('Phone', 'East', 900.00),
    ('Tablet', 'West', 425.00),
    ('Monitor', 'East', 680.00),
    ('Keyboard', 'South', 80.00),
    ('Laptop', 'West', 1300.00),
    ('Phone', 'West', 820.00),
]

# %% [markdown]
# ## Lab 1. Total sales by region

# %%
def region_total(data, region):
    return sum(amt for _, r, amt in data if r == region)
# This goes through each record in sales_data

# %%
print(region_total(sales_data, 'East'))
print(region_total(sales_data, 'West'))
print(region_total(sales_data, 'South'))
# Out:
# 3180.0
# 3470.0
# 1880.0

# %% [markdown]
# ### This function looks through the sales data, finds only the records that match the region, adds up their sale amounts, and returns the total.

# %% [markdown]
# ## Lab 2. Count of sales by region

# %%
def region_count(data, region):
    return sum(1 for _, r, amt in data if r == region)

# %%
print(region_count(sales_data, 'East'))
print(region_count(sales_data, 'West'))
print(region_count(sales_data, 'South'))
# Out:
# 4
# 5
# 3

# %% [markdown]
# ## Lab 3. Average sale amount by region

# %%
def region_average(data, region):
    count = region_count(data, region)

    if count == 0:
        return 0

    total = region_total(data, region)
    average = total / count

    return average

# %%
print(region_average(sales_data, 'East'))
print(region_average(sales_data, 'West'))
print(region_average(sales_data, 'South'))
print(region_average(sales_data, 'North'))
# Out:
# 795.0
# 694.0
# 626.6666666666666
# 0

# %% [markdown]
# ## Lab 4. Filter by sale amount

# %%
def sales_above(data, threshold):
    return [record for record in data if record[2] > threshold]

# %%
high_sales = sales_above(sales_data, 500)

for record in high_sales:
    print(record)
# Out:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Monitor', 'South', 650.0)
# ('Laptop', 'South', 1150.0)
# ('Phone', 'East', 900.0)
# ('Monitor', 'East', 680.0)
# ('Laptop', 'West', 1300.0)
# ('Phone', 'West', 820.0)

# %%
def sales_below(data, threshold):
    return [record for record in data if record[2] < threshold]

# %%
low_sales = sales_below(sales_data, 500)

for record in low_sales:
    print(record)
# Out:
# ('Tablet', 'East', 400.0)
# ('Keyboard', 'West', 75.0)
# ('Tablet', 'West', 425.0)
# ('Keyboard', 'South', 80.0)

# %% [markdown]
# ## Lab 5. Top and bottom sale

# %%
def top_sale(data):
    return max(data, key=lambda s: s[2])


def bottom_sale(data):
    return min(data, key=lambda s: s[2])

# %%
top = top_sale(sales_data)
bottom = bottom_sale(sales_data)

print(top)
print(bottom)
# Out:
# ('Laptop', 'West', 1300.0)
# ('Keyboard', 'West', 75.0)

# %% [markdown]
# The top sale was a Laptop in the West region for $1,300.00.
#
# The bottom sale was a Keyboard in the West region for $75.00.

# %% [markdown]
# ## Lab 6. Apply a discount

# %%
def apply_discount(data, discount_pct):
    return list(map(lambda s: (s[0], s[1], s[2] * (1 - discount_pct)), data))

# %%
discounted_sales = apply_discount(sales_data, 0.15)

print("Before discount:")
for record in sales_data[:3]:
    print(record)

print()

print("After discount:")
for record in discounted_sales[:3]:
    print(record)
# Out:
# Before discount:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Tablet', 'East', 400.0)
#
# After discount:
# ('Laptop', 'East', 1020.0)
# ('Phone', 'West', 722.5)
# ('Tablet', 'East', 340.0)

# %% [markdown]
# ## Lab 7. Unique regions

# %%
def unique_regions(data):
    return sorted(set(region for _, region, amt in data))

# %%
print(unique_regions(sales_data))
# Out:
# ['East', 'South', 'West']

# %% [markdown]
# This function is useful because it helps me find all the different regions in the dataset without repeating any region names.
# In a longer analysis program, I could use this pattern to create summaries by region, filter data by category, or
# automatically loop through each group without hardcoding the names.

# %% [markdown]
# ## Lab 8. Region summary

# %%
def region_summary(data, region):
    region_records = [record for record in data if record[1] == region]

    if len(region_records) == 0:
        print(f"No records found for {region}.")
        return

    total = region_total(data, region)
    count = region_count(data, region)
    average = region_average(data, region)
    top = top_sale(region_records)

    print(f"""
=== {region} Region ===
Records: {count}
Total Sales: ${total:,.2f}
Average Sale: ${average:,.2f}
Top Sale: {top[0]} — ${top[2]:,.2f}
""")

# %%
region_summary(sales_data, 'East')
region_summary(sales_data, 'West')
region_summary(sales_data, 'South')
# Out:
# === East Region ===
# Records: 4
# Total Sales: $3,180.00
# Average Sale: $795.00
# Top Sale: Laptop — $1,200.00
#
#
# === West Region ===
# Records: 5
# Total Sales: $3,470.00
# Average Sale: $694.00
# Top Sale: Laptop — $1,300.00
#
#
# === South Region ===
# Records: 3
# Total Sales: $1,880.00
# Average Sale: $626.67
# Top Sale: Laptop — $1,150.00

# %% [markdown]
# ## Lab 9. Full summary

# %%
for region in unique_regions(sales_data):
    region_summary(sales_data, region)
# Out:
# === East Region ===
# Records: 4
# Total Sales: $3,180.00
# Average Sale: $795.00
# Top Sale: Laptop — $1,200.00
#
#
# === South Region ===
# Records: 3
# Total Sales: $1,880.00
# Average Sale: $626.67
# Top Sale: Laptop — $1,150.00
#
#
# === West Region ===
# Records: 5
# Total Sales: $3,470.00
# Average Sale: $694.00
# Top Sale: Laptop — $1,300.00

# %% [markdown]
# In this set of labs, I learned how to use Python functions to analyze a small sales dataset. I practiced creating functions that calculate totals, counts, averages, top sales, bottom sales, filtered sales, discounts, and unique regions. I also learned how functions can work together, because some functions reused other functions instead of repeating the same logic. This helped me understand how Python functions make analysis cleaner, easier to read, and easier to reuse.

# %% [markdown]
# ### This lab is showing how functions can help analyze data. Instead of writing the same calculations over and over, each function handles one job, like finding the total sales, counting records, calculating averages, or filtering sales above a certain amount. Then the final labs combine those smaller functions into a full summary report.
